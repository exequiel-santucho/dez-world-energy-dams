# %%
import pandas as pd

# %% [markdown]
# ### World Energy Consumption

# %%
df1 = pd.read_csv('../data/world_energy_consumption.csv')
df1.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
df1.loc[(df1['iso_code']=='AFG') & (df1['year']>=2000)]['hydro_electricity'].head()
# Out:
# 123    0.31
# 124    0.50
# 125    0.56
# 126    0.63
# 127    0.56
# Name: hydro_electricity, dtype: float64

# %%
len(df1)
# Out:
# 22012

# %%
df1.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=129)

# %%
df1.dtypes
# Out:
# country                    object
# year                        int64
# iso_code                   object
# population                float64
# gdp                       float64
#                            ...
# wind_elec_per_capita      float64
# wind_electricity          float64
# wind_energy_per_capita    float64
# wind_share_elec           float64
# wind_share_energy         float64
# Length: 129, dtype: object

# %%
df1.isnull().sum()
# Out:
# country                       0
# year                          0
# iso_code                   5500
# population                 3889
# gdp                       10899
#                           ...
# wind_elec_per_capita      14947
# wind_electricity          14016
# wind_energy_per_capita    17947
# wind_share_elec           15126
# wind_share_energy         17911
# Length: 129, dtype: int64

# %%
df1.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct  \
# count  22012.000000  1.812300e+04  1.111300e+04              1747.000000
# mean    1974.213247  1.053096e+08  3.585114e+11                46.091694
# std       35.058653  4.640460e+08  2.411179e+12               274.616745
# min     1900.000000  1.833000e+03  1.642060e+08              -100.000000
# 25%     1946.000000  1.712404e+06  1.365898e+10                -0.616500
# 50%     1984.000000  6.991543e+06  4.167411e+10                 8.179000
# 75%     2003.000000  2.557688e+07  1.744295e+11                26.508500
# max     2022.000000  7.975105e+09  1.136302e+14              5659.328000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              2687.000000              2302.000000          2767.000000
# mean                  2.719074               133.558459            38.068209
# std                  10.057018               264.707851           111.623148
# ...

# %%
df1_sub = df1[['country', 'year', 'electricity_demand', 'electricity_generation']]
df1_sub
# Out:
#              country  year  electricity_demand  electricity_generation
# 0      ASEAN (Ember)  2000              368.65                  368.65
# 1      ASEAN (Ember)  2001              397.19                  397.19
# 2      ASEAN (Ember)  2002              422.82                  422.82
# 3      ASEAN (Ember)  2003              447.15                  447.15
# 4      ASEAN (Ember)  2004              484.94                  484.94
# ...              ...   ...                 ...                     ...
# 22007       Zimbabwe  2018               10.21                    9.19
# 22008       Zimbabwe  2019                9.35                    8.24
# 22009       Zimbabwe  2020                9.57                    7.59
# 22010       Zimbabwe  2021                9.78                    8.03
# 22011       Zimbabwe  2022                 NaN                     NaN
#
# [22012 rows x 4 columns]

# %% [markdown]
# ### Hydropower Generation

# %%
df2 = pd.read_csv('../data/hydropower_generation.csv')
df2.head()
# Out:
#        Country   2000   2001   2002   2003   2004   2005   2006   2007   2008  \
# 0  Afghanistan    312    498    555     63    565     59    637    748    542
# 1       Africa  75246  80864  85181  82873  87405  89066  92241  95341  97157
# 2      Albania   4548   3519   3477   5117   5411   5319   4951    276   3759
# 3      Algeria     54     69     57    265    251    555    218    226    283
# 4       Angola    903   1007   1132   1229   1733   2197   2638   2472   3103
#
#    ...    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0  ...     751     595      71     804     895     989    1025     105
# 1  ...  107427  110445  110952  117673  123727  115801  123816  130388
# 2  ...    7673    4036    4725    6959    4726    5866    7136     448
# 3  ...     173     378     389      99     193     145      72      56
# 4  ...    3666    3967    3734    4719    4991    5037    5757    7576
#
#      2018  2019
# 0     105   107
# 1  132735     0
# 2     448  4018
# ...

# %%
df2.columns
# Out:
# Index(['Country', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# Country    object
# 2000        int64
# 2001        int64
# 2002        int64
# 2003        int64
# 2004        int64
# 2005        int64
# 2006        int64
# 2007        int64
# 2008        int64
# 2009        int64
# 2010        int64
# 2011        int64
# 2012        int64
# 2013        int64
# 2014        int64
# 2015        int64
# 2016        int64
# 2017        int64
# 2018        int64
# 2019        int64
# dtype: object

# %%
df2.describe()
# Out:
#                 2000           2001           2002           2003  \
# count     153.000000     153.000000     153.000000     153.000000
# mean    21648.078431   21611.424837   22447.915033   20558.183007
# std     81404.562424   77239.960541   80813.611084   78158.375672
# min         0.000000       0.000000       0.000000       0.000000
# 25%       152.000000     158.000000     182.000000     164.000000
# 50%      1758.000000    1821.000000    1668.000000    1671.000000
# 75%      7699.000000    7814.000000    7524.000000    7374.000000
# max    662596.000000  612041.000000  632304.000000  625963.000000
#
#                 2004           2005           2006           2007  \
# count     153.000000     153.000000     153.000000     153.000000
# mean    26227.039216   25577.418301   27790.013072   27683.803922
# std     85898.531613   89497.140747   91369.382369   91901.135874
# min         0.000000       0.000000       0.000000       1.000000
# ...

# %% [markdown]
# ### Global Dams

# %%
df3= pd.read_csv('../data/global_dams.csv', encoding='latin-1')
df3.head()
# Out:
#         Country  ISO Sec_cntry     Name           AltDamName     Purpose  \
# 0  Burkina Faso  BFA       NaN  Manessa  Kouilwoko / Namessa  Irrigation
# 1       Nigeria  NGA       NaN    Ouree                  NaN  Hydropower
# 2       Nigeria  NGA       NaN    Tenti                  NaN  Hydropower
# 3  Burkina Faso  BFA       NaN     Soaw                  NaN         NaN
# 4  Burkina Faso  BFA       NaN  Loumana                Dalan         NaN
#
#    Admin_unit Near_city    River  Main_basin  ... Compensa_1 Gov_guaran  \
# 0  Oubritenga    Daplgo  Nakanbe  West Coast  ...        NaN        NaN
# 1     Plateau       NaN    Ouree         NaN  ...        NaN        NaN
# 2     Plateau     Tenti      NaN         NaN  ...        NaN        NaN
# 3  Boulkiemde      Soaw  Mouhoun  West Coast  ...        NaN        NaN
# 4      Leraba   Loumana    Comoe  West Coast  ...        NaN        NaN
#
#                                           Regulatory  \
# ...

# %%
df3.columns
# Out:
# Index(['Country', 'ISO', 'Sec_cntry', 'Name', 'AltDamName', 'Purpose',
#        'Admin_unit', 'Near_city', 'River', 'Main_basin', 'Sub_basin', 'Status',
#        'PVOUT', 'PotentialPVSurface', 'PV_InstalledCapacity', 'PV_SpaCapacity',
#        'Dam_hgt', 'Res_capacityM3', 'Res_area_km2', 'HPP_Install_Cap',
#        'Transm_exist', 'Transm_length', 'Transm_plan', 'Proj_type',
#        'Lifecycle', 'Storage_ty', 'Linked_prj', 'Proj_cost', 'Proj_statu',
#        'Study_stat', 'YEAR', 'Yr_recents', 'Comission_', 'Ann_firm_g',
#        'Ann_tot_ge', 'Prox_irrig', 'Size_irrig', 'Owner', 'Autom_EMS_',
#        'PrivateOwn', 'Feed_in_ta', 'Feed_in__1', 'Guaranteed', 'Competitiv',
#        'Winning_bi', 'OtherFisca', 'Prioritize', 'Priority_d', 'Compensati',
#        'Compensa_1', 'Gov_guaran', 'Regulatory', 'Download', 'Long__res_',
#        'Lat__res_', 'Lat__hydro', 'Long__hydr', 'Database', 'Notes'],
#       dtype='object')

# %%
df3 = df3[['Country', 'ISO', 'Purpose']]
df3.head()
# Out:
#         Country  ISO     Purpose
# 0  Burkina Faso  BFA  Irrigation
# 1       Nigeria  NGA  Hydropower
# 2       Nigeria  NGA  Hydropower
# 3  Burkina Faso  BFA         NaN
# 4  Burkina Faso  BFA         NaN

# %%
df3.dtypes
# Out:
# Country    object
# ISO        object
# Purpose    object
# dtype: object

# %%
df3.loc[df3['Country'] == 'United States'].head()
# Out:
#             Country  ISO           Purpose
# 3450  United States  USA  Hydroelectricity
# 3451  United States  USA  Hydroelectricity
# 3452  United States  USA  Hydroelectricity
# 3453  United States  USA  Hydroelectricity
# 3454  United States  USA  Hydroelectricity
